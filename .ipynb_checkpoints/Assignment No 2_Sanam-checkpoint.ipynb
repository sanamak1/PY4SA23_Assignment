# %% [markdown]
# # Lab Assignment No 2 - Sanam
# #### 200019305
# #### https://github.com/sanamak1/Assignment_2

# %% [markdown]
# Task 1: Create an If...Else statement that will test whether a number is divisible by three. "YOUR
# VALUE is divisible by 3" should be printed if the value is divisible by three. "YOUR VALUE is not
# divisible by three" should be printed if it is not divisible by three. Test the statement on a numeric
# variable. Upper case text in the print statement should be replaced with the tested number.

# %%
if x%3 == 0:
    print(x, 'is divisible by 3')
else:
    print(x, 'is not divisble by 3')
    
x=9
# Out:
# 9 is divisible by 3

# %% [markdown]
# T2: Create an If...Else statement that will test whether a type of fruit, represented as a text string,
# is in a list of acceptable fruits (apple, orange, pear, kiwi, or strawberry). If the fruit is on the list, the
# following should be printed: "YOUR FRUIT is acceptable." If not, then the following should be
# printed: "YOUR FRUIT is not acceptable." Upper case text in the print statement should be replaced
# with the tested fruit.

# %%
FruitList = ["apple", "orange", "pear", "kiwi", "strawberry"]
x = "lemon"
if x in FruitList:
    print(x, 'is acceptable')
else:
    print(x, 'is not acceptable')
# Out:
# lemon is not acceptable

# %% [markdown]
# T3: Create a function to calculate the distance between two coordinates using the haversine
# formula. Write the following formula where the input parameters are a pair of coordinates as two
# lists.

# %% [markdown]
# a = sin²(φB - φA/2) + cos φA * cos φB * sin²(λB - λA/2)
# c = 2 * atan2( √a, √(1−a) )
# d = R ⋅ c

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lat1, lon1, lat2, lon2):

      R = 6371 

      dLat = radians(lat2 - lat1)
      dLon = radians(lon2 - lon1)
      lat1 = radians(lat1)
      lat2 = radians(lat2)

      a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
      c = 2*asin(sqrt(a))

      return R * c

lon1 = -2.8
lat1 = 56.3
lon2 = -3.5
lat2 = 56.4

print(haversine(lat1, lon1, lat2, lon2))
# Out:
# 44.54067182131459

# %% [markdown]
# ## Numpy and Pandas

# %%
import pandas as pd
import numpy as np

# %%
#with this command I read the datafile
df = pd.read_csv('Assignment 2 Data/portland_park_trees.csv')

# %%
df
# Out:
#          fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  \
# 0          1       426  2017/05/09    PSME  37.4      Fair       105.0
# 1          2       427  2017/05/09    PSME  32.5      Fair        94.0
# 2          3       428  2017/05/09    CRLA   9.7      Fair        23.0
# 3          4       429  2017/05/09    QURU  10.3      Poor        28.0
# 4          5       430  2017/05/09    PSME  33.2      Fair       102.0
# ...      ...       ...         ...     ...   ...       ...         ...
# 25529  25530    726046  2018/08/16    QURU  31.6      Fair        74.0
# 25530  25531    726443  2019/10/11    PSME   0.4      Good         8.0
# 25531  25532    726444  2019/10/11    MEGL  26.3      Fair        79.0
# 25532  25533    726445  2019/10/11    PCSI   8.8      Fair        43.0
# 25533  25534    726446  2019/10/11    COKO   2.0      Good        18.0
#
#        CrownWidth  CrownWid_1 CollectedB  ...        Genus        Common_nam  \
# ...

# %% [markdown]
# Question 1: How many trees are of the Quercus or Acer genus?

# %%
# Here I performed a query to select trees with Quercus or Acer genuses.
nquercusgenus = df.query('Genus == "Quercus" or Genus == "Acer"')
print('there are' len(nquercusgenus.index) 'trees with Quercus or Acer genuses')
# Out:
#   Cell In[22], line 3
#     print('there are' len(nquercusgenus.index) 'trees with Quercus or Acer genuses')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Q1 Answer: There are 3586 trees with the Genus Acer, and 2089 trees with the genus Quercus, or 5675 in total.

# %% [markdown]
# Q2: How many trees are of the Quercus or Acer genus and have a DBH larger than 50 inches?

# %%
#df.query('Genus == "Quercus" or Genus == "Acer"')
#df.query('DBH > 50')
#tree_sample = (df.query('Genus == "Quercus" or Genus == "Acer"') &
             #  df.query('DBH > 50'))
#df[(df["Genus"]=="Quercus") or (df["Genus"]=="Acer") & (df["DBH"]>50)]
#print(tree_sample.head)
#df.query('DBH > 50 & Genus == "Quercus" or Genus == "Acer"')
#df.query('DBH >50') & ('Genus == "Quercus"') or ('Genus == "Acer"')

tree_sample = df.query('DBH > 50')
tree_sample.query('Genus == "Quercus" or Genus == "Acer"')
# Out:
#          fid  OBJECTID  Inventory_ Species   DBH Condition  TreeHeight  \
# 127      128       953  2017/05/24    ACMA  50.5      Fair        90.0
# 152      153      1754  2017/05/24    ACMA  50.5      Fair        85.0
# 154      155      1756  2017/05/24    ACMA  52.7      Fair        94.0
# 162      163      2150  2017/05/24    ACMA  56.3      Fair        70.0
# 593      594     13044  2017/06/29    ACMA  50.9      Fair        90.0
# ...      ...       ...         ...     ...   ...       ...         ...
# 23957  23958    684418  2019/09/23    ACMA  59.5      Poor        77.0
# 24271  24272    690856  2019/09/25    QUGA  69.9      Good       101.0
# 24461  24462    695648  2019/09/27    QUGA  59.0      Fair        94.0
# 25499  25500    723643  2019/10/11    ACMA  84.5      Fair        69.0
# 25506  25507    724045  2019/10/11    ACMA  63.0      Poor        46.0
#
#        CrownWidth  CrownWid_1 CollectedB  ...    Genus        Common_nam  \
# ...

# %% [markdown]
# Q2 answer: there are 124 trees which have a DBH higher than 50 and are of the Acer or Quercus genus.

# %% [markdown]
# Q3: Which genus has the highest mean DBH of the following genera: Quercus, Acer, or Fraxinus?

# %%
#here I created three subsets of the data, one for each of the genera that I was interested in.
# Then, I used the .mean() function to find the mean for each one, so I could compare them to each other.
quercus = df.query('Genus == "Quercus"')
quercus["DBH"].mean()
# Out:
# 23.56823839157492

# %%
acer = df.query('Genus == "Acer"')
acer["DBH"].mean()
# Out:
# 18.419085331846066

# %%
fraxinus = df.query('Genus == "Fraxinus"')
fraxinus["DBH"].mean()
# Out:
# 11.033609693877551

# %% [markdown]
# Q3 answer: Quercus has the highest mean DBH of the three genera.

# %% [markdown]
# Q4: How many different species of trees are recorded in the Acer genus?

# %%
# Using the subset I created from the previous question, I used the nunique() function 
# to see how many unique values there were in the Species column, showing how many different species there were
acer['Species'].nunique()
# Out:
# 20

# %% [markdown]
# Q4 answer: there are 20 different species of trees in the Acer genus.

# %%
world = pd.read_csv('Assignment 2 Data/world_cities.csv')

# %% [markdown]
# Calculate a new column named "pop_M" (population in millions), by transforming the
# "pop" (population) column.

# %%
world["pop_M"] = world["pop"]
world
# Out:
#                      city       country     pop    lat    lon  capital   pop_M
# 0      'Abasan al-Jadidah     Palestine    5629  31.31  34.34        0    5629
# 1      'Abasan al-Kabirah     Palestine   18999  31.32  34.35        0   18999
# 2            'Abdul Hakim      Pakistan   47788  30.55  72.11        0   47788
# 3      'Abdullah-as-Salam        Kuwait   21817  29.36  47.98        0   21817
# 4                   'Abud     Palestine    2456  32.03  35.07        0    2456
# ...                   ...           ...     ...    ...    ...      ...     ...
# 43640           az-Zubayr          Iraq  124611  30.39  47.71        0  124611
# 43641            az-Zulfi  Saudi Arabia   54070  26.30  44.80        0   54070
# 43642       az-Zuwaytinah         Libya   21984  30.95  20.12        0   21984
# 43643        s-Gravenhage   Netherlands  479525  52.07   4.30        0  479525
# 43644     s-Hertogenbosch   Netherlands  135529  51.68   5.30        0  135529
#
# ...

# %% [markdown]
#  Remove the original "pop" column.

# %%
world.drop(columns=['pop'])
# Out:
#                      city       country    lat    lon  capital   pop_M
# 0      'Abasan al-Jadidah     Palestine  31.31  34.34        0    5629
# 1      'Abasan al-Kabirah     Palestine  31.32  34.35        0   18999
# 2            'Abdul Hakim      Pakistan  30.55  72.11        0   47788
# 3      'Abdullah-as-Salam        Kuwait  29.36  47.98        0   21817
# 4                   'Abud     Palestine  32.03  35.07        0    2456
# ...                   ...           ...    ...    ...      ...     ...
# 43640           az-Zubayr          Iraq  30.39  47.71        0  124611
# 43641            az-Zulfi  Saudi Arabia  26.30  44.80        0   54070
# 43642       az-Zuwaytinah         Libya  30.95  20.12        0   21984
# 43643        s-Gravenhage   Netherlands  52.07   4.30        0  479525
# 43644     s-Hertogenbosch   Netherlands  51.68   5.30        0  135529
#
# [43645 rows x 6 columns]

# %% [markdown]
# • Choose/subset a city that starts with the same letter as your first name (for example,
# "Mexico City" if your first name is Michael).

# %%
# To subset this data I created a subset called stockholm
# I performed a query on my dataset which specified that the 'city' column 
# should include only the value Stockholm. 
stockholm = world.query('city == "Stockholm"')
stockholm
# Out:
#             city country      pop    lat    lon  capital    pop_M
# 36248  Stockholm  Sweden  1260712  59.33  18.07        1  1260712

# %% [markdown]
# • Subset the five biggest (i.e., largest population sizes) cities from the country where your
# selected city is.
# • Print the result.

# %%
# To subset the five biggest cities in Sweden, I made a subset called sweden_cities.
# In this subset I performed a query of the dataset, to identify all cities which were in Sweden. 
# I used the sort_value function to specify that the data should be sorted in ascending order 
# according to population size. I also specified that the subset should only include the 5 cities
# with the largest populations.

sweden_cities = (world.query('country == "Sweden"')
   .sort_values(by="pop", ascending=False)
   .head(5))
print(sweden_cities)
# Out:
#             city country      pop    lat    lon  capital    pop_M
# 36248  Stockholm  Sweden  1260712  59.33  18.07        1  1260712
# 12867   Goteborg  Sweden   518990  57.72  12.01        0   518990
# 22388      Malmo  Sweden   264175  55.61  13.02        0   264175
# 39601    Uppsala  Sweden   128374  59.86  17.64        0   128374
# 40164   Vasteras  Sweden   108127  59.62  16.54        0   108127

# %% [markdown]
# ## Python Data Visualisation

# %% [markdown]
# Graph 1: Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis
# and tree height mapped to the y-axis (Hint: You will need to use the “Genus”, “DBH”, and
# “TreeHeight” attributes.).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# First I created a subset of the Ulmus genus.
# Then I used seaborn's scatterplot function, plotting DBH for x and TreeHeight for y.
ulmus = df.query('Genus == "Ulmus"')
sns.scatterplot(x="DBH", y="TreeHeight", data=ulmus)
# Out:
# <AxesSubplot: xlabel='DBH', ylabel='TreeHeight'>

# %% [markdown]
# G2: Create a scatterplot for just trees in the Ulmus genus with DBH mapped to the x-axis, tree
# height mapped to the y-axis, and tree species mapped to hue (Hint: You will need to use the
# “Genus”, “Genus_spec”, “DBH”, and “TreeHeight” attributes.)

# %%
ulmus = df.query('Genus == "Ulmus"')
sns.scatterplot(x="DBH", y="TreeHeight", hue="Genus_spec", data=ulmus)
# Out:
# <AxesSubplot: xlabel='DBH', ylabel='TreeHeight'>

# %% [markdown]
# G3: Create a boxplot of DBH for just the Ulmus genus differentiated by species (or, each species
# should have its own boxplot).

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(data=ulmus, x='DBH', y='Genus_spec')
plt.title('Box Plot')
plt.show()
#????

# %% [markdown]
# G4: Combine Graphs 1 and 3 into a single figure. Do not plot a legend for any of the graphs.

# %%
#graph_3 = sns.boxplot(data=ulmus, x='DBH', y='Genus_spec')
#graph_1 = sns.scatterplot(x="DBH", y="TreeHeight", data=ulmus)
fig1, axs = plt.subplots(1,2)
axs[0].boxplot(ulmus.DBH, ulmus.Genus_spec)
axs[1].scatter(ulmus.DBH, ulmus.TreeHeight)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 #graph_3 = sns.boxplot(data=ulmus, x='DBH', y='Genus_spec')
#       2 #graph_1 = sns.scatterplot(x="DBH", y="TreeHeight", data=ulmus)
#       3 fig1, axs = plt.subplots(1,2)
# ----> 4 axs[0].boxplot(ulmus.DBH, ulmus.Genus_spec)
#       5 axs[1].scatter(ulmus.DBH, ulmus.TreeHeight)
#
# File ~/miniconda3/envs/py4sa/lib/python3.10/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# -> 1433         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1435     bound = new_sig.bind(ax, *args, **kwargs)
#    1436     auto_label = (bound.arguments.get(label_namer)
#    1437                   or bound.kwargs.get(label_namer))
#
# ...

# %% [markdown]
# ## Python Geopandas

# %%
import geopandas as gpd
stat = gpd.read_file('FGS_SMF_Native_Woodlands.shp')

# %% [markdown]
# T2: Use the correct code to plot the first 5 and the last 5 sets of records in your selected dataset.

# %%
stat.iloc[0:5].plot

# %% [markdown]
# T3. Create a map where you can explore the selected dataset. Try to plot the map using some
# categorical attribute. Include a ToolTip.

# %% [markdown]
# T4. What is the Coordinate Reference System of the selected dataset?

# %%
stat.crs
# Out:
# <Derived Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
print('The CRS is EPSG: 3857')
# Out:
# The CRS is EPSG: 3857

# %% [markdown]
# T5. How many features does the selected dataset contain?

# %%
stat.shape
# Out:
# (53, 7)

# %%
print('The dataset has 53 features')
# Out:
# The dataset has 53 features

# %% [markdown]
# T6. Define a sub-setting criterion to create a new geopandas dataframe where you filter the
# selected dataset based on a categorical attribute.

# %% [markdown]
# T7. Define a sub-setting criterion to create a new geopandas dataframe where you filter the
# selected dataset based on a numerical attribute.

# %% [markdown]
# T8. Plot the new/filtered geopandas dataframe using one of the attributes to create a
# choropleth map

# %% [markdown]
# ## Rasterio

# %%
import rasterio as rio
import earthpy as et
import earthpy.plot as ep

# %%
elev = rio.open("Assignment 2 Data/elev.tif")

# %% [markdown]
# T2: What is the CRS of the dataset?

# %%
print(elev.crs)
# Out:
# EPSG:32617

# %% [markdown]
# T3: Describe the raster dataset regarding the raster extent (bounds), the reference system, and
# how many bands are in this dataset.

# %%
print(elev.bounds)
print(elev.count)
# Out:
# BoundingBox(left=479753.39945587853, bottom=4170823.2037591375, right=668843.3994558785, top=4347733.203759138)
# 1

# %% [markdown]
# T4: Create a plot/map of the raster dataset

# %%
elev_arr = elev.read(1)
ep.plot_bands(elev_arr,
              title="Elev",
              cmap="gist_earth")

plt.show()

# %% [markdown]
# T5: Create Histograms from the raster.

# %%
ep.hist(elev_arr,
        figsize=(10, 6))
plt.show()
